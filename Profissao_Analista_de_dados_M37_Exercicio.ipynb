# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Amazon Web Services;</li>
#   <li>AWS IAM;</li>
#   <li>AWS S3;</li>
#   <li>AWS Athena.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Amazon Web Services

# %% [markdown]
#  1. Crie uma conta na [AWS](https://portal.aws.amazon.com/);
#  1. Acesse a sua conta e selecione a região mais próxima da sua residência.

# %% [markdown]
# ## 2\. AWS S3

# %% [markdown]
# Replique as atividades do item 3.3 em sua conta.
#
# 1- Gerar o arquivo  iris.csv

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Carregar o conjunto de dados Iris
iris = load_iris()

# Criar um DataFrame com os dados
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target

# Salvar o DataFrame em um arquivo CSV
iris_df.to_csv('iris.csv', index=False)

print("Arquivo iris.csv criado com sucesso!")
# Out:
# Arquivo iris.csv criado com sucesso!

# %% [markdown]
# criar bucket
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# carregar objeto
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# carga do objeto efetivada
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3\. AWS Athena

# %% [markdown]
# Replique as atividades do item 4.3 em sua conta.
#
#
# consultas
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# resultado da query
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# consultas limite 10
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  falhou
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# consulta especie
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# falhou
#
# ![image.png](data:image/png;base64,...)
